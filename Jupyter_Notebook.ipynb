# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Andres Felipe Velez Gruezo**

# %% [markdown]
# Agronomic engineer

# %% [markdown]
# *Im interested in data science because I'm working in this area and realizing activities that involve the management of many information.*

# %% [markdown]
# ### My code is a D20 dice that I'm going to use for the game dungeons and dragon

# %%
import random

min = 1
max = 20

Flag = "yes"

while Flag == "yes" or Flag == "y" :
    print("Now Rolling the dice...")
    print ("Number on the dice is: ")
    print (random.randint(min, max))
    Flag = input("Are you interested to Roll the dice again? ")
